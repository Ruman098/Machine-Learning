# %% [markdown]
# # Pandas Excercises

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('survey_results_public.csv')

# %%
#pd.set_option('display.max_columns', 79)
#pd.set_option('display.max_rows', 79)

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv')

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
df.head(5)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6  I am not primarily a developer, but I write co...
# 6           7                        I code primarily as a hobby
# 7           8                     I am a developer by profession
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# ...

# %%
df.tail(10)
# Out:
#        ResponseId                                         MainBranch  \
# 73258       73259                     I am a developer by profession
# 73259       73260                     I am a developer by profession
# 73260       73261                     I am a developer by profession
# 73261       73262                     I am a developer by profession
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73258                                Employed, full-time
# 73259                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['Employment']
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4                                      Employed, full-time
#                                ...
# 73263                                  Employed, full-time
# 73264                                  Employed, full-time
# 73265                                  Employed, full-time
# 73266                                  Employed, full-time
# 73267    Independent contractor, freelancer, or self-em...
# Name: Employment, Length: 73268, dtype: object

# %%
type(df['Employment'])
# Out:
# pandas.core.series.Series

# %%
df[['Employment', 'LearnCode']]
# Out:
#                                               Employment  \
# 0                                                    NaN
# 1                                    Employed, full-time
# 2                                    Employed, full-time
# 3                                    Employed, full-time
# 4                                    Employed, full-time
# ...                                                  ...
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                                LearnCode
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# ...

# %%
df.iloc[0]
# Out:
# ResponseId                         1
# MainBranch             None of these
# Employment                       NaN
# RemoteWork                       NaN
# CodingActivities                 NaN
#                            ...
# TrueFalse_2                      NaN
# TrueFalse_3                      NaN
# SurveyLength                     NaN
# SurveyEase                       NaN
# ConvertedCompYearly              NaN
# Name: 0, Length: 79, dtype: object

# %%
df.iloc[5]
# Out:
# ResponseId                                                             6
# MainBranch             I am not primarily a developer, but I write co...
# Employment                                            Student, full-time
# RemoteWork                                                           NaN
# CodingActivities                                                     NaN
#                                              ...
# TrueFalse_2                                                          NaN
# TrueFalse_3                                                          NaN
# SurveyLength                                       Appropriate in length
# SurveyEase                                                          Easy
# ConvertedCompYearly                                                  NaN
# Name: 5, Length: 79, dtype: object

# %%
df.iloc[0 : 3, 0 : 3]
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
#
#             Employment
# 0                  NaN
# 1  Employed, full-time
# 2  Employed, full-time

# %%
df.loc[0]
# Out:
# ResponseId                         1
# MainBranch             None of these
# Employment                       NaN
# RemoteWork                       NaN
# CodingActivities                 NaN
#                            ...
# TrueFalse_2                      NaN
# TrueFalse_3                      NaN
# SurveyLength                     NaN
# SurveyEase                       NaN
# ConvertedCompYearly              NaN
# Name: 0, Length: 79, dtype: object

# %%
df.iloc[0 : 5, 2 : 10]
# Out:
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %%
df.iloc[1 : 4, 2 : 4]
# Out:
#             Employment                            RemoteWork
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote

# %%
schema_df
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
schema_df['force_resp'].value_counts()
# Out:
# force_resp
# False    62
# True      4
# Name: count, dtype: int64

# %%
schema_df.sort_index()
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2     QID1           S1  <span style="font-size:22px; font-family: aria...
# 3     QID2   MainBranch  Which of the following options best describes ...
# 4   QID296   Employment  Which of the following best describes your cur...
# ..     ...          ...                                                ...
# 74  QID290  Frequency_2  Interacting with people outside of your immedi...
# 75  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
# 76  QID294  TrueFalse_1  Are you involved in supporting new hires durin...
# 77  QID294  TrueFalse_2  Do you use learning resources provided by your...
# 78  QID294  TrueFalse_3  Does your employer give you time to learn new ...
#
#    force_resp  type selector
# 0       False    DB       TB
# ...

# %%
schema_df.set_index('qname', inplace = True)

# %%
schema_df
# Out:
#                 qid                                           question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# S1             QID1  <span style="font-size:22px; font-family: aria...
# MainBranch     QID2  Which of the following options best describes ...
# Employment   QID296  Which of the following best describes your cur...
# ...             ...                                                ...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
# TrueFalse_1  QID294  Are you involved in supporting new hires durin...
# TrueFalse_2  QID294  Do you use learning resources provided by your...
# TrueFalse_3  QID294  Does your employer give you time to learn new ...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# ...

# %%
schema_df.sort_index(inplace = True)

# %%
schema_df.head()
# Out:
#                      qid                                           question  \
# qname
# Accessibility     QID124  Which of the following describe you, if any? P...
# Age               QID127                                  What is your age?
# Blockchain        QID305  How favorable are you about blockchain, crypto...
# BuyNewTool        QID279  When buying a new tool or software, how do you...
# CodingActivities  QID297  Which of the following best describes the code...
#
#                  force_resp type selector
# qname
# Accessibility         False   MC     MAVR
# Age                   False   MC     MAVR
# Blockchain            False   MC     SAVR
# BuyNewTool            False   MC     MAVR
# CodingActivities      False   MC     MAVR

# %%
schema_df.index
# Out:
# Index(['Accessibility', 'Age', 'Blockchain', 'BuyNewTool', 'CodingActivities',
#        'CompFreq', 'CompTotal', 'Country', 'Currency', 'Database', 'DevType',
#        'EdLevel', 'Employment', 'Ethnicity', 'Frequency', 'Frequency_1',
#        'Frequency_2', 'Frequency_3', 'Gender', 'ICorPM', 'Knowledge',
#        'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
#        'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Language', 'LearnCode',
#        'LearnCodeCoursesCert', 'LearnCodeOnline', 'MainBranch', 'MentalHealth',
#        'MetaInfo', 'MiscTech', 'NEWCollabTools', 'NEWSOSites',
#        'OfficeStackAsync', 'OfficeStackSync', 'Onboarding', 'OpSys', 'OrgSize',
#        'Platform', 'ProfessionalTech', 'PurchaseInfluence', 'RemoteWork', 'S0',
#        'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'SOAccount', 'SOComm',
#        'SOPartFreq', 'SOTeamsUsage', 'SOVisitFreq', 'Sexuality', 'SurveyEase',
#        'SurveyLength', 'TBranch', 'TimeAnswering', 'TimeSearching',
# ...

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
schema_df.loc['Accessibility','question']
# Out:
# 'Which of the following describe you, if any? Please check all that apply. '

# %% [markdown]
# # Filtering out from a dataframe

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df['SurveyLength'].value_counts()
# Out:
# SurveyLength
# Appropriate in length    53883
# Too long                 14491
# Too short                 2070
# Name: count, dtype: int64

# %%
filt = (df['SurveyLength'] == 'Too long')
df.loc[filt, ['SurveyEase', 'Currency']]
# Out:
#                        SurveyEase                   Currency
# 1                       Difficult       CAD\tCanadian dollar
# 4                            Easy  USD\tUnited States dollar
# 22     Neither easy nor difficult       CAD\tCanadian dollar
# 29                           Easy          EUR European Euro
# 34                           Easy          PLN\tPolish zloty
# ...                           ...                        ...
# 73237  Neither easy nor difficult          IRR\tIranian rial
# 73255  Neither easy nor difficult          INR\tIndian rupee
# 73258  Neither easy nor difficult          INR\tIndian rupee
# 73263                        Easy  USD\tUnited States dollar
# 73264                        Easy  USD\tUnited States dollar
#
# [14491 rows x 2 columns]

# %%
df.loc[2, ['SurveyEase']]
# Out:
# SurveyEase    Neither easy nor difficult
# Name: 2, dtype: object

# %% [markdown]
# # Practices

# %%
babynames = pd.Series([
    'Jathonathon', 'Zeltron', 'Ruger', 'Phreddy', 'Ruger', 'Chad', 'Chad',
    'Ruger', 'Ryan', 'Ruger', 'Chad', 'Ryan', 'Phreddy', 'Phreddy', 'Phreddy',
    'Mister', 'Zeltron', 'Ryan', 'Ruger', 'Ruger', 'Jathonathon',
    'Jathonathon', 'Ruger', 'Chad', 'Zeltron'], dtype='string')

# %%
df = pd.DataFrame(babynames)

# %%
df
# Out:
#               0
# 0   Jathonathon
# 1       Zeltron
# 2         Ruger
# 3       Phreddy
# 4         Ruger
# 5          Chad
# 6          Chad
# 7         Ruger
# 8          Ryan
# 9         Ruger
# 10         Chad
# 11         Ryan
# 12      Phreddy
# 13      Phreddy
# 14      Phreddy
# 15       Mister
# 16      Zeltron
# 17         Ryan
# 18        Ruger
# 19        Ruger
# 20  Jathonathon
# 21  Jathonathon
# 22        Ruger
# 23         Chad
# 24      Zeltron

# %%
df.value_counts().loc[['Ruger', 'Chad', 'Zeltron']]
# Out:
# 0
# Ruger      7
# Chad       4
# Zeltron    3
# Name: count, dtype: int64

# %%
bees = pd.Series([True, True, False, np.nan, True, False, True, np.nan])
knees = pd.Series([5,2,9,1,3,10,5,2], index = [7,0,2,6,3,5,1,4])

# %%
knees.loc[pd.isna(bees).to_numpy] *= 2

# %%
knees
# Out:
# 7    10
# 0     4
# 2     9
# 6     1
# 3     6
# 5    10
# 1    10
# 4     2
# dtype: int64

# %%
asking_prices = pd.Series([5000, 7600, 9000, 8500, 7000], index=['civic', 'civic', 'camry', 'mustang', 'mustang'])
fair_prices = pd.Series([5500, 7500, 7500], index=['civic', 'mustang', 'camry'])

# %%
df1 = pd.
